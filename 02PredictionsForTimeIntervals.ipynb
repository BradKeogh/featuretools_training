# %% [markdown]
# # 02 predictions for time intervals
#
# Relating patient/attendance transactional dataframes to a daily or hourly dataframe requires a many-to-many link, which is not possible directly in ft. A linking dataframe can be used which does not contain unique keys, and can be joined on both sides with a many relationship.

# %%
import pandas as pd
import numpy as np
import featuretools as ft
from create_data import make_attendances_dataframe

# %%
df = make_attendances_dataframe(15)

# %% [markdown]
# #### create all dataframes we need

# %%
from create_data import make_timeindex_dataframe, make_HourlyTimeAttenNum_dataframe

# %%
df_ActiveVisits = make_HourlyTimeAttenNum_dataframe(df,'arrival_datetime','departure_datetime')
df_ActiveVisits.head()
# Out:
#    atten_id                hour
# 0         5 2018-01-01 02:00:00
# 1         5 2018-01-01 03:00:00
# 2         5 2018-01-01 04:00:00
# 3         5 2018-01-01 05:00:00
# 4         5 2018-01-01 06:00:00

# %%
df_hours = make_timeindex_dataframe(df,'hour','h')
df_hours.head(3)
# Out:
#                  hour
# 0 2018-01-01 00:00:00
# 1 2018-01-01 01:00:00
# 2 2018-01-01 02:00:00

# %%
df_days = make_timeindex_dataframe(df,'day','D')
df_days.head(3)
# Out:
#          day
# 0 2018-01-01
# 1 2018-01-02
# 2 2018-01-03

# %% [markdown]
# #### Make entitity sets - as before

# %%
import featuretools.variable_types as vtypes
data_variable_types = {'atten_id': vtypes.Id,
                       'pat_id': vtypes.Id,
                       'arrival_datetime': vtypes.Datetime,
                      'time_in_department': vtypes.Numeric,
                       'departure_datetime': vtypes.Datetime,
                       'gender': vtypes.Boolean,
                      'ambulance_arrival': vtypes.Boolean}
es = ft.EntitySet('Hospital')
es = es.entity_from_dataframe(entity_id='attendances',
                               dataframe=df,
                               index='atten_id',
                               time_index='arrival_datetime',
                              secondary_time_index={'departure_datetime':['time_in_department']}, # dictionary here!
                               variable_types=data_variable_types)

# %% [markdown]
# #### make entity with each attendance and hour it is active

# %%
df_ActiveVisits.head(3)
# Out:
#    atten_id                hour
# 0         5 2018-01-01 02:00:00
# 1         5 2018-01-01 03:00:00
# 2         5 2018-01-01 04:00:00

# %%
# Make linking-es (active_visits)
es = es.entity_from_dataframe(entity_id='active_visits',
                               dataframe=df_ActiveVisits,
                              make_index=True,
                              index='index',
                               variable_types={'atten_id':vtypes.Id,
                                              'hour':vtypes.Datetime})

# %% [markdown]
# #### make entity with hourly index

# %%
df_hours.head(3)
# Out:
#                  hour
# 0 2018-01-01 00:00:00
# 1 2018-01-01 01:00:00
# 2 2018-01-01 02:00:00

# %%
# Make hours eset
es = es.entity_from_dataframe(entity_id='hours',
                               dataframe=df_hours,
                               index='hour',
                               variable_types={'hour':vtypes.Datetime})

# %% [markdown]
# As we have made more entities with dataframes (and not normalised them from existing entities) we must explicitly tell the entity set the relationships:

# %%
# add es relationships
rel_Atten_ActiveVisits = ft.Relationship(es["attendances"]["atten_id"],
                                    es["active_visits"]["atten_id"])
rel_Hours_ActiveVisits = ft.Relationship(es["hours"]["hour"],
                                    es["active_visits"]["hour"])
es = es.add_relationships([rel_Atten_ActiveVisits,rel_Hours_ActiveVisits])

# %% [markdown]
# #### creating features for individual hours
#
# Now we have all our entities linked we can run DFS on the entity "hours". This will generate features like  "COUNT(active_visits)" -> in other words -> "Occupancy" for that particlar time of day.

# %%
fm, features = ft.dfs(entityset=es,
                     target_entity='hours',
#                     agg_primitives=[],
#                     trans_primitives=[],
                     verbose=True,
                     max_depth = 5)
fm.head(5)
# Out:
# Built 41 features
# Elapsed: 00:00 | Remaining: 00:00 | Progress: 100%|███████████| Calculated: 5/5 chunks
#                      COUNT(active_visits)  NUM_UNIQUE(active_visits.atten_id)  \
# hour
# 2018-01-01 00:00:00                   0.0                                 NaN
# 2018-01-01 01:00:00                   0.0                                 NaN
# 2018-01-01 02:00:00                   1.0                                 1.0
# 2018-01-01 03:00:00                   1.0                                 1.0
# 2018-01-01 04:00:00                   1.0                                 1.0
#
#                      MODE(active_visits.atten_id)  \
# hour
# 2018-01-01 00:00:00                           NaN
# 2018-01-01 01:00:00                           NaN
# 2018-01-01 02:00:00                           5.0
# 2018-01-01 03:00:00                           5.0
# 2018-01-01 04:00:00                           5.0
#
#                      SUM(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                0.0
# 2018-01-01 01:00:00                                                0.0
# 2018-01-01 02:00:00                                                0.0
# 2018-01-01 03:00:00                                                0.0
# 2018-01-01 04:00:00                                                0.0
#
#                      STD(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MAX(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      SKEW(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MIN(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MEAN(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      NUM_UNIQUE(active_visits.attendances.pat_id)  \
# hour
# 2018-01-01 00:00:00                                           NaN
# 2018-01-01 01:00:00                                           NaN
# 2018-01-01 02:00:00                                           0.0
# 2018-01-01 03:00:00                                           0.0
# 2018-01-01 04:00:00                                           0.0
#
#                                                 ...                               \
# hour                                            ...
# 2018-01-01 00:00:00                             ...
# 2018-01-01 01:00:00                             ...
# 2018-01-01 02:00:00                             ...
# 2018-01-01 03:00:00                             ...
# 2018-01-01 04:00:00                             ...
#
#                      NUM_UNIQUE(active_visits.attendances.WEEKDAY(departure_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                0.0
# 2018-01-01 03:00:00                                                0.0
# 2018-01-01 04:00:00                                                0.0
#
#                      MODE(active_visits.attendances.MODE(active_visits.hour))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.DAY(arrival_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.DAY(departure_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.YEAR(arrival_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.YEAR(departure_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.MONTH(arrival_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.MONTH(departure_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.WEEKDAY(arrival_datetime))  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MODE(active_visits.attendances.WEEKDAY(departure_datetime))
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
# [5 rows x 41 columns]

# %%
features
# Out:
# [<Feature: COUNT(active_visits)>,
#  <Feature: NUM_UNIQUE(active_visits.atten_id)>,
#  <Feature: MODE(active_visits.atten_id)>,
#  <Feature: SUM(active_visits.attendances.time_in_department)>,
#  <Feature: STD(active_visits.attendances.time_in_department)>,
#  <Feature: MAX(active_visits.attendances.time_in_department)>,
#  <Feature: SKEW(active_visits.attendances.time_in_department)>,
#  <Feature: MIN(active_visits.attendances.time_in_department)>,
#  <Feature: MEAN(active_visits.attendances.time_in_department)>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.pat_id)>,
#  <Feature: MODE(active_visits.attendances.pat_id)>,
#  <Feature: SUM(active_visits.attendances.COUNT(active_visits))>,
#  <Feature: SUM(active_visits.attendances.NUM_UNIQUE(active_visits.hour))>,
#  <Feature: STD(active_visits.attendances.COUNT(active_visits))>,
#  <Feature: STD(active_visits.attendances.NUM_UNIQUE(active_visits.hour))>,
#  <Feature: MAX(active_visits.attendances.COUNT(active_visits))>,
#  <Feature: MAX(active_visits.attendances.NUM_UNIQUE(active_visits.hour))>,
#  <Feature: SKEW(active_visits.attendances.COUNT(active_visits))>,
#  <Feature: SKEW(active_visits.attendances.NUM_UNIQUE(active_visits.hour))>,
#  <Feature: MIN(active_visits.attendances.COUNT(active_visits))>,
#  <Feature: MIN(active_visits.attendances.NUM_UNIQUE(active_visits.hour))>,
#  <Feature: MEAN(active_visits.attendances.COUNT(active_visits))>,
#  <Feature: MEAN(active_visits.attendances.NUM_UNIQUE(active_visits.hour))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.MODE(active_visits.hour))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.DAY(arrival_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.DAY(departure_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.YEAR(arrival_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.YEAR(departure_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.MONTH(arrival_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.MONTH(departure_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.WEEKDAY(arrival_datetime))>,
#  <Feature: NUM_UNIQUE(active_visits.attendances.WEEKDAY(departure_datetime))>,
#  <Feature: MODE(active_visits.attendances.MODE(active_visits.hour))>,
#  <Feature: MODE(active_visits.attendances.DAY(arrival_datetime))>,
#  <Feature: MODE(active_visits.attendances.DAY(departure_datetime))>,
#  <Feature: MODE(active_visits.attendances.YEAR(arrival_datetime))>,
#  <Feature: MODE(active_visits.attendances.YEAR(departure_datetime))>,
#  <Feature: MODE(active_visits.attendances.MONTH(arrival_datetime))>,
#  <Feature: MODE(active_visits.attendances.MONTH(departure_datetime))>,
#  <Feature: MODE(active_visits.attendances.WEEKDAY(arrival_datetime))>,
#  <Feature: MODE(active_visits.attendances.WEEKDAY(departure_datetime))>]

# %%
fm.dropna(axis=1).head()
# Out:
#                      COUNT(active_visits)  \
# hour
# 2018-01-01 00:00:00                   0.0
# 2018-01-01 01:00:00                   0.0
# 2018-01-01 02:00:00                   1.0
# 2018-01-01 03:00:00                   1.0
# 2018-01-01 04:00:00                   1.0
#
#                      SUM(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                0.0
# 2018-01-01 01:00:00                                                0.0
# 2018-01-01 02:00:00                                                0.0
# 2018-01-01 03:00:00                                                0.0
# 2018-01-01 04:00:00                                                0.0
#
#                      SUM(active_visits.attendances.COUNT(active_visits))  \
# hour
# 2018-01-01 00:00:00                                                0.0
# 2018-01-01 01:00:00                                                0.0
# 2018-01-01 02:00:00                                                0.0
# 2018-01-01 03:00:00                                                0.0
# 2018-01-01 04:00:00                                                0.0
#
#                      SUM(active_visits.attendances.NUM_UNIQUE(active_visits.hour))
# hour
# 2018-01-01 00:00:00                                                0.0
# 2018-01-01 01:00:00                                                0.0
# 2018-01-01 02:00:00                                                0.0
# 2018-01-01 03:00:00                                                0.0
# 2018-01-01 04:00:00                                                0.0

# %% [markdown]
# # Further notes

# %% [markdown]
# #### adding "Intesting" variables

# %%
df.head()
# Out:
#    atten_id  pat_id    arrival_datetime  time_in_department  \
# 5      1005     992 2018-01-01 02:49:00                 197
# 9      1009   10281 2018-01-01 05:39:00                 122
# 4      1004    4471 2018-01-01 08:07:00                  89
# 0      1000    8416 2018-01-01 08:15:00                  59
# 6      1006     472 2018-01-01 11:21:00                 303
#
#    ambulance_arrival  departure_datetime  gender
# 5                  1 2018-01-01 06:06:00       0
# 9                  0 2018-01-01 07:41:00       1
# 4                  1 2018-01-01 09:36:00       1
# 0                  0 2018-01-01 09:14:00       0
# 6                  1 2018-01-01 16:24:00       0

# %%
es["attendances"]["ambulance_arrival"].interesting_values = [True, False]

# %%
fm, features = ft.dfs(entityset=es,
                     target_entity='hours',
                     agg_primitives=['count','mean','percent_true'],
                     trans_primitives=[],
                      where_primitives=['count'],
                     verbose=True,
                     max_depth = 8)
fm.head(5)
# Out:
# Built 3 features
# Elapsed: 00:00 | Remaining: 00:00 | Progress: 100%|███████████| Calculated: 5/5 chunks
#                      COUNT(active_visits)  \
# hour
# 2018-01-01 00:00:00                   0.0
# 2018-01-01 01:00:00                   0.0
# 2018-01-01 02:00:00                   1.0
# 2018-01-01 03:00:00                   1.0
# 2018-01-01 04:00:00                   1.0
#
#                      MEAN(active_visits.attendances.time_in_department)  \
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN
#
#                      MEAN(active_visits.attendances.COUNT(active_visits))
# hour
# 2018-01-01 00:00:00                                                NaN
# 2018-01-01 01:00:00                                                NaN
# 2018-01-01 02:00:00                                                NaN
# 2018-01-01 03:00:00                                                NaN
# 2018-01-01 04:00:00                                                NaN

# %%
ft.list_primitives()
# Out:
#                    name         type  \
# 0                  skew  aggregation
# 1                median  aggregation
# 2      avg_time_between  aggregation
# 3       time_since_last  aggregation
# 4                  mode  aggregation
# 5                 count  aggregation
# 6                   any  aggregation
# 7                   all  aggregation
# 8                   min  aggregation
# 9                  last  aggregation
# 10                 mean  aggregation
# 11             num_true  aggregation
# 12         percent_true  aggregation
# 13        n_most_common  aggregation
# 14                trend  aggregation
# 15                  max  aggregation
# 16                  sum  aggregation
# 17                  std  aggregation
# 18           num_unique  aggregation
# 19              weekend    transform
# 20           characters    transform
# 21            longitude    transform
# 22              is_null    transform
# 23                   or    transform
# 24               divide    transform
# 25           days_since    transform
# 26                  not    transform
# 27                 week    transform
# 28               second    transform
# 29              cum_sum    transform
# ..                  ...          ...
# 32              seconds    transform
# 33                month    transform
# 34           time_since    transform
# 35                 diff    transform
# 36                hours    transform
# 37                 days    transform
# 38                 year    transform
# 39             cum_mean    transform
# 40            haversine    transform
# 41  time_since_previous    transform
# 42              minutes    transform
# 43                 hour    transform
# 44             numwords    transform
# 45                  add    transform
# 46           percentile    transform
# 47             absolute    transform
# 48              cum_min    transform
# 49              cum_max    transform
# 50                  mod    transform
# 51               months    transform
# 52                weeks    transform
# 53             subtract    transform
# 54              weekday    transform
# 55                 isin    transform
# 56            cum_count    transform
# 57                  and    transform
# 58             multiply    transform
# 59               minute    transform
# 60                  day    transform
# 61                years    transform
#
#                                           description
# 0                Computes the skewness of a data set.
# 1   Finds the median value of any feature with wel...
# 2   Computes the average time between consecutive ...
# 3                   Time since last related instance.
# 4   Finds the most common element in a categorical...
# 5               Counts the number of non null values.
# 6                        Test if any value is 'True'.
# 7                      Test if all values are 'True'.
# 8   Finds the minimum non-null value of a numeric ...
# 9                             Returns the last value.
# 10   Computes the average value of a numeric feature.
# 11    Finds the number of 'True' values in a boolean.
# 12  Finds the percent of 'True' values in a boolea...
# 13  Finds the N most common elements in a categori...
# 14  Calculates the slope of the linear trend of va...
# 15  Finds the maximum non-null value of a numeric ...
# 16     Sums elements of a numeric or boolean feature.
# 17  Finds the standard deviation of a numeric feat...
# 18  Returns the number of unique categorical varia...
# 19  Transform Datetime feature into the boolean of...
# 20           Return the characters in a given string.
# 21  Returns the second value on the tuple base fea...
# 22  For each value of base feature, return 'True' ...
# 23  For two boolean values, determine if one value...
# 24  Creates a transform feature that divides two f...
# 25  For each value of the base feature, compute th...
# 26  For each value of the base feature, negates th...
# 27        Transform a Datetime feature into the week.
# 28      Transform a Datetime feature into the second.
# 29  Calculates the sum of previous values of an in...
# ..                                                ...
# 32  Transform a Timedelta feature into the number ...
# 33       Transform a Datetime feature into the month.
# 34             Calculates time since the cutoff time.
# 35  Compute the difference between the value of a ...
# 36  Transform a Timedelta feature into the number ...
# 37  Transform a Timedelta feature into the number ...
# 38        Transform a Datetime feature into the year.
# 39  Calculates the mean of previous values of an i...
# 40  Calculate the approximate haversine distance i...
# 41      Compute the time since the previous instance.
# 42  Transform a Timedelta feature into the number ...
# 43        Transform a Datetime feature into the hour.
# 44  Returns the words in a given string by countin...
# 45  Creates a transform feature that adds two feat...
# 46  For each value of the base feature, determines...
# 47                    Absolute value of base feature.
# 48  Calculates the min of previous values of an in...
# 49  Calculates the max of previous values of an in...
# 50  Creates a transform feature that divides two f...
# 51  Transform a Timedelta feature into the number ...
# 52  Transform a Timedelta feature into the number ...
# 53  Creates a transform feature that subtracts two...
# 54  Transform Datetime feature into the boolean of...
# 55  For each value of the base feature, checks whe...
# 56  Calculates the number of previous values of an...
# 57  For two boolean values, determine if both valu...
# 58  Creates a transform feature that multplies two...
# 59      Transform a Datetime feature into the minute.
# 60         Transform a Datetime feature into the day.
# 61  Transform a Timedelta feature into the number ...
#
# [62 rows x 3 columns]
